# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, r2_score
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge,ElasticNet, LogisticRegression
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier 
import warnings
warnings.filterwarnings('ignore')

# %%
conc=pd.read_csv(r'C:\Users\Administrator.DAI-PC2\Desktop\jupiter_demo\ML\Cases-20240426T111123Z-001\Cases\Concrete Strength\Concrete_Data.csv')
conc.head()
X = conc.drop('Strength',axis=1)
y = conc['Strength']

# %%
 poly3 = PolynomialFeatures(degree=3).set_output(transform='pandas')
x_poly3 = poly3.fit_transform(X)
x_poly3
# Out:
#         1  Cement  Blast    Fly  Water  Superplasticizer  Coarse   Fine  \
# 0     1.0   540.0    0.0    0.0  162.0               2.5  1040.0  676.0
# 1     1.0   540.0    0.0    0.0  162.0               2.5  1055.0  676.0
# 2     1.0   332.5  142.5    0.0  228.0               0.0   932.0  594.0
# 3     1.0   332.5  142.5    0.0  228.0               0.0   932.0  594.0
# 4     1.0   198.6  132.4    0.0  192.0               0.0   978.4  825.5
# ...   ...     ...    ...    ...    ...               ...     ...    ...
# 1025  1.0   276.4  116.0   90.3  179.6               8.9   870.1  768.3
# 1026  1.0   322.2    0.0  115.6  196.0              10.4   817.9  813.4
# 1027  1.0   148.5  139.4  108.6  192.7               6.1   892.4  780.0
# 1028  1.0   159.1  186.7    0.0  175.6              11.3   989.6  788.9
# 1029  1.0   260.9  100.5   78.3  200.6               8.6   864.5  761.5
#
#         Age   Cement^2  ...      Coarse^3  Coarse^2 Fine  Coarse^2 Age  \
# 0      28.0  291600.00  ...  1.124864e+09   7.311616e+08  3.028480e+07
# 1      28.0  291600.00  ...  1.174241e+09   7.524049e+08  3.116470e+07
# 2     270.0  110556.25  ...  8.095576e+08   5.159627e+08  2.345285e+08
# 3     365.0  110556.25  ...  8.095576e+08   5.159627e+08  3.170478e+08
# 4     360.0   39441.96  ...  9.365896e+08   7.902235e+08  3.446160e+08
# ...     ...        ...  ...           ...            ...           ...
# 1025   28.0   76396.96  ...  6.587301e+08   5.816600e+08  2.119807e+07
# 1026   28.0  103812.84  ...  5.471427e+08   5.441324e+08  1.873089e+07
# 1027   28.0   22052.25  ...  7.106875e+08   6.211747e+08  2.229858e+07
# 1028   28.0   25312.81  ...  9.691234e+08   7.725762e+08  2.742063e+07
# 1029   28.0   68068.81  ...  6.460929e+08   5.691148e+08  2.092609e+07
#
#       Coarse Fine^2  Coarse Fine Age  Coarse Age^2        Fine^3  \
# 0      4.752550e+08     1.968512e+07      815360.0  3.089158e+08
# 1      4.821097e+08     1.996904e+07      827120.0  3.089158e+08
# 2      3.288432e+08     1.494742e+08    67942800.0  2.095846e+08
# 3      3.288432e+08     2.020669e+08   124165700.0  2.095846e+08
# 4      6.667309e+08     2.907609e+08   126800640.0  5.625372e+08
# ...             ...              ...           ...           ...
# 1025   5.136069e+08     1.871794e+07      682158.4  4.535159e+08
# 1026   5.411386e+08     1.862784e+07      641233.6  5.381614e+08
# 1027   5.429362e+08     1.949002e+07      699641.6  4.745520e+08
# 1028   6.158906e+08     2.185947e+07      775846.4  4.909823e+08
# 1029   5.013082e+08     1.843287e+07      677768.0  4.415803e+08
#
#         Fine^2 Age   Fine Age^2       Age^3
# 0     1.279533e+07     529984.0     21952.0
# 1     1.279533e+07     529984.0     21952.0
# 2     9.526572e+07   43302600.0  19683000.0
# 3     1.287851e+08   79135650.0  48627125.0
# 4     2.453221e+08  106984800.0  46656000.0
# ...            ...          ...         ...
# 1025  1.652798e+07     602347.2     21952.0
# 1026  1.852535e+07     637705.6     21952.0
# 1027  1.703520e+07     611520.0     21952.0
# 1028  1.742617e+07     618497.6     21952.0
# 1029  1.623670e+07     597016.0     21952.0
#
# [1030 rows x 165 columns]

# %%
lr = LinearRegression()
X_train,X_test,y_train,y_test = train_test_split(x_poly3,y,test_size=0.3,random_state=24)

# %%
y_pred = lr.predict(X_test)

# %%
y_pred = lr.predict(X_test)

# %%
#######  KNN   ##############
kyp= pd.read_csv(r'C:\Users\Administrator.DAI-PC2\Desktop\jupiter_demo\ML\Cases-20240426T111123Z-001\Cases\Kyphosis\Kyphosis.csv')
knn = KNeighborsClassifier(n_neighbors=5)

le = LabelEncoder()
y=le.fit_transform(kyp['Kyphosis'])
X = kyp.drop('Kyphosis',axis=1)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=24)

# %%
knn.fit(X_train,y_train)
y_pred= knn.predict(X_test)
y_pred_prob=knn.predict_proba(X_test)
print(accuracy_score(y_test,y_pred))
print(roc_auc_score(y_test,y_pred_prob[:,1]))
print(log_loss(y_test,y_pred_prob))
# Out:
# 0.72
# 0.6491228070175439
# 1.857105559203503

# %%
######### grid search########

kfold=StratifiedKFold(n_splits=5,shuffle=True,random_state=24)
params={'n_neighbors':[1,2,3,4,5,6]}
knn= KNeighborsClassifier()
gcv=GridSearchCV(knn,param_grid=params,cv=kfold,scoring='neg_log_loss')
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'n_neighbors': 6}
# -1.2640562465635274
